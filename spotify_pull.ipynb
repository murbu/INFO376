# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.25.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-7.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests>=2.25.0 in c:\users\yuanxili\code\info376\.venv\lib\site-packages (from spotipy) (2.32.5)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\yuanxili\code\info376\.venv\lib\site-packages (from spotipy) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yuanxili\code\info376\.venv\lib\site-packages (from requests>=2.25.0->spotipy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yuanxili\code\info376\.venv\lib\site-packages (from requests>=2.25.0->spotipy) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yuanxili\code\info376\.venv\lib\site-packages (from requests>=2.25.0->spotipy) (2026.1.4)
# Downloading spotipy-2.25.2-py3-none-any.whl (31 kB)
# Downloading redis-7.2.0-py3-none-any.whl (394 kB)
# Installing collected packages: redis, spotipy
#
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    ---------------------------------------- 0/2 [redis]
#    -------------------- ------------------- 1/2 [spotipy]
#    -------------------- ------------------- 1/2 [spotipy]
#    ---------------------------------------- 2/2 [spotipy]
#
# Successfully installed redis-7.2.0 spotipy-2.25.2
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd


CLIENT_ID = 'f4fe5e4437a14fbfa90919182e11308a'
CLIENT_SECRET = '9de966dee672440ebc30046f6397e8ed'
REDIRECT_URI = 'https://google.com' 


sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=CLIENT_ID,
    client_secret=CLIENT_SECRET,
    redirect_uri=REDIRECT_URI,
    scope="playlist-read-private" 
))


results = sp.search(q='Jay Chou', limit=10, type='album')


albums = results['albums']['items']
df = pd.DataFrame(albums)


print(df[['name', 'release_date', 'total_tracks']])
# Out:
#        name release_date  total_tracks
# 0       七里香   2004-08-03            10
# 1       范特西   2001-09-14            10
# 2    11月的蕭邦   2005-11-11            12
# 3       魔杰座   2008-10-15            11
# 4    最偉大的作品   2022-07-15            12
# 5        杰倫   2000-11-16            10
# 6      八度空間   2002-07-18            10
# 7       葉惠美   2003-07-29            11
# 8       我很忙   2007-11-02            10
# 9  周杰倫的床邊故事   2016-06-24            10
